# %% [markdown]
# ---
# # **Pandas - WhitePaper**
# # **Data Analysis with Pandas 🐼**
# ---

# %% [markdown]
# Notebook Created by:
#
# - **V. D. Betancourt**

# %% [markdown]
# **WhitePaper**
#
#
#
# *   Enache, Maria Cristina (2019). [Data Analysis with Pandas](https://web.archive.org/web/20191211022945id_/http://www.eia.feaa.ugal.ro/images/eia/2019_2/Enache1.pdf). *Journal of Data Analysis*.
#
#     *  DOI: [10.35219/eai1584040933](http://dx.doi.org/10.35219/eai1584040933)

# %% [markdown]
# ---
# # **Índice**
# ---

# %% [markdown]
# * [1. Introducción](#1)
#
#
# * [2. Principales Ideas](#2)
#
#
# * [3. Settings](#3)
#
#
# * [4. Comparación de Datos](#4)
#
#
# * [5. Selección de Datos](#5)
#
#
# * [6. Filtrado de Datos con Condición Simple](#6)
#
#
#
# * [7. Filtrado de Datos con Condiciones Múltiples](#7)
#
#
#
# * [8. Conclusiones](#8)
#
#
#
# * [9. Bibliografía](#9)

# %% [markdown]
# ---
# <a id="1"></a>
#
# ## 🌄 **Introducción**
#
# ---

# %% [markdown]
# El ***Análisis de Datos (Data Analysis, DA)*** se ha convertido en una herramienta clave para las empresas modernas, no solo como un medio para limpiar, analizar y modelar información, sino como un pilar fundamental para desarrollar estrategias de marketing efectivas y alcanzar resultados comerciales deseados.
#
# A pesar de que no todas las compañías han reconocido aún la importancia de emplear análisis de Big Data para maximizar sus beneficios, el Análisis de Datos se destaca por su velocidad y precisión en la toma de decisiones de negocio. Esta disciplina no solo proporciona exactitud, sino que también ofrece módulos estadísticos robustos y herramientas de alta tecnología para el Análisis de Datos.
#
# Dentro de este panorama, ***Python*** se destaca como un lenguaje idóneo para el Análisis de Datos, principalmente gracias a su fantástico ecosistema de paquetes orientados a datos. Entre estos paquetes se encuentra ***Pandas***, una librería de código abierto que simplifica significativamente la importación y el Análisis de Datos, siendo un componente esencial en el kit de herramientas de cualquier analista.
#
# El presente Notebook explora las ideas presentadas en el paper denominado:
#
# *   Enache, Maria Cristina (2019). [Data Analysis with Pandas](https://web.archive.org/web/20191211022945id_/http://www.eia.feaa.ugal.ro/images/eia/2019_2/Enache1.pdf). *Journal of Data Analysis*.

# %% [markdown]
# ---
# <a id="2"></a>
#
# ## 💡 **Principales Ideas**
#
# ---

# %% [markdown]
# "***Data Analytics***" y "***Data Analysis***" son términos que a menudo se utilizan de manera intercambiable, pero tienen diferencias sutiles en su enfoque y aplicación.

# %% [markdown]
# ---
# ### **Data Analysis vs Data Analytics**
#
# ---

# %% [markdown]
# *   **Data Analytics** es el proceso y la metodología general para analizar los datos con el fin obtener hallazgos significativos de los mismos. Suele clasificarse en 3 tipos:
#   *  Descriptive Analytics
#   *  Predictive Analytics
#   *  Prescriptive Analytics
#
#
#
# *   **Data Analysis** se refiere a los actos individuales de analizar los datos. Implica limpiar y transformar los datos con el objetivo de descubrir información útil.

# %% [markdown]
# ---
# ### **Big Data vs Data Analytics**
#
# ---

# %% [markdown]
# *   **Big Data**: Se centra en los desafíos asociados con el manejo de datos "grandes" no tradicionales. El Big Data aborda problemas como la velocidad, variedad y volumen de los datos, buscando maneras de gestionar y obtener valor de conjuntos de datos masivos y a menudo desestructurados.
#
# *   **Data Analytics**: Se enfoca en obtener información significativa de los datos, independientemente del tamaño de estos. Utiliza técnicas estadísticas, algoritmos y herramientas analíticas para interpretar, descubrir patrones y extraer conocimientos útiles de los datos, ya sean grandes o pequeños.

# %% [markdown]
# En lo sucesivo, se replicarán y explicarán los ejemplos expuestos por la autora Enache, se harán las observaciones que se consideren pertinentes y si fuese el caso, se aportarán mejoras al código.

# %% [markdown]
# ---
# <a id="3"></a>
#
# ## ⚙️ **Settings**
#
# ---

# %%
# import pandas package
import pandas as pd

# %% [markdown]
# 👩‍💻 **La Autora Enache**

# %% [markdown]
# ```
# # Código Original de la Autora
#
# # import pandas package
# import pandas as pd
#
# # Define a dictionary containing data
# data = {'Nume':['Ion', 'Silviu', 'Maria', 'Vasile', 'Marin', 'Petru'],
#  'Sex':[ 'M', 'M', 'F', 'M', 'M', 'M'],
#  Management':['False', 'True', 'False','False', 'True', 'False']
#  Echipa':['Mk','Finante,'Mk', 'Productie','Resurse Umane','Juridic']}
#
# # create DataFrame
# df = pd.DataFrame(data)
#
# # select two columns
# print(df[['Nume', 'Sex']])
#
#
#
# ```

# %% [markdown]
# En este fragmento, se importa el paquete Pandas, se define un diccionario con datos y se crea un DataFrame a partir de este diccionario. Luego, se seleccionan y muestran dos columnas del DataFrame, '**`Nume`**' (Nombres) y '**`Sex`**' (Sexo).

# %% [markdown]
# ⚠️ **Warning!**
#
# Hay un error de sintaxis en la definición del diccionario data, falta una coma entre los valores de '**`Management`**' y '**`Echipa`**'. Además, '**`Finante`**' en la lista de '**`Echipa`**' debería estar entre comillas para ser consistente.

# %%
# Código Corregido

# Define a dictionary containing data
data = {'Nume':['Ion', 'Silviu', 'Maria', 'Vasile', 'Marin', 'Petru'],
 'Sex':[ 'M', 'M', 'F', 'M', 'M', 'M'],
 'Management':['False', 'True', 'False','False', 'True', 'False'],
 'Echipa':['Mk','Finante','Mk', 'Productie','Resurse Umane','Juridic']}


# create DataFrame
df = pd.DataFrame(data)

# Backup del Original
original = df.copy()

# select two columns
print(df[['Nume', 'Sex']])
# Out:
#      Nume Sex
# 0     Ion   M
# 1  Silviu   M
# 2   Maria   F
# 3  Vasile   M
# 4   Marin   M
# 5   Petru   M

# %% [markdown]
# ---
# <a id="4"></a>
#
# ## **Comparación de Datos**
#
# ---

# %% [markdown]
# 👩‍💻 **La Autora Enache**

# %% [markdown]
# El primer ejemplo proporcionado por la autora, tiene que ver con la ***Comparación de Datos*** usando Pandas.
#
# Se crea una serie booleana mediante la comparación de cada elemento en la columna '**`Sex`**' con el valor "**`M`**". Esta serie booleana se añade como una nueva columna al DataFrame.

# %% [markdown]
# ```
# # Código Original de la Autora
#
# # importing pandas package
# import pandas as pd
#
# # making data frame from csv file
# data = pd.read_csv("angajat.csv")
#
# # storing boolean series in new
# new = data["Sex"] == "M"
#
# # inserting new series in data frame
# data["New"]= new
#
# # display
# data
#
#
# ```

# %% [markdown]
# ⚠️ **Warning!**
#
# El dataset citado por la autora, **`angajat.csv`**, no está disponible. Por lo que, se asume que se utilizará el DataFrame (**`df`**) definido anteriormente.

# %%
# Código Corregido

# Se está suponiendo que data = df

# storing boolean series in new
new = data["Sex"] == "M"

# inserting new series in data frame
data["New"]= new

# display
data
# Out:
# {'Nume': ['Ion', 'Silviu', 'Maria', 'Vasile', 'Marin', 'Petru'],
#  'Sex': ['M', 'M', 'F', 'M', 'M', 'M'],
#  'Management': ['False', 'True', 'False', 'False', 'True', 'False'],
#  'Echipa': ['Mk', 'Finante', 'Mk', 'Productie', 'Resurse Umane', 'Juridic'],
#  'New': False}

# %% [markdown]
# **Comentarios Propios**

# %% [markdown]
# *  El concepto de ***comparar valores y almacenar el resultado*** en una nueva columna es una práctica común en el análisis de datos.
#
# *  Sin embargo, el código podría mejorarse en términos de eficiencia y claridad. Por ejemplo, en lugar de almacenar el resultado en una nueva columna, se podría utilizar directamente dicha ***columna para filtrar*** el DataFrame si ese fuera el objetivo final.
#
# *  Además, sería útil incluir un ***manejo de errores*** en caso de que el archivo CSV no exista o tenga un formato incorrecto.

# %% [markdown]
# ---
# <a id="5"></a>
#
# ## **Selección de Datos**
#
# ---

# %% [markdown]
# 👩‍💻 **La Autora Enache**

# %% [markdown]
# El siguiente Ejemplo de la autora, pretende demostrar cómo ***seleccionar datos*** de un DataFrame en Pandas basándose en una condición específica.
#
# El código crea una serie booleana (new) donde cada valor es True si el valor correspondiente en la columna '**`Sex`**' del DataFrame data no es "**`Female`**".
#
# Esta serie booleana se añade como una nueva columna '**`New`**' al DataFrame.
#
# Finalmente, se muestran solamente aquellas filas del DataFrame donde la condición de la columna '**`New`**' es **`True`**, es decir, donde '**`Sex`**' no es "**`Female`**".

# %% [markdown]
# ```
# # Código Original de la Autora
#
# # importing pandas package
# import pandas as pd
#
# # making data frame from csv file
# data = pd.read_csv("angajat.csv")
# storing boolean series in new
# new = data["Sex"] != "Female"
#
# # inserting new series in data frame
# data["New"]= new
#
# # display
# data[new]
#
#
# ```

# %% [markdown]
# ⚠️ **Warning!**
#
# *  El dataset citado por la autora, **`angajat.csv`**, no está disponible. Por lo que, se asume que se utilizará el DataFrame (**`df`**) definido anteriormente.
#
# *  Adicionalmente, hay un error en la línea que debería ser un comentario: `#storing boolean series in new`

# %%
# Código Corregido

# Se está suponiendo que data = df

data = df

#storing boolean series in new
new = data["Sex"] != "Female"

# inserting new series in data frame
data["New"]= new

# display
data[new]
# Out:
#      Nume Sex Management         Echipa   New
# 0     Ion   M      False             Mk  True
# 1  Silviu   M       True        Finante  True
# 2   Maria   F      False             Mk  True
# 3  Vasile   M      False      Productie  True
# 4   Marin   M       True  Resurse Umane  True
# 5   Petru   M      False        Juridic  True

# %% [markdown]
# **Comentarios Propios**
#
#
#
# *   La creación de una nueva columna '**`New`**' podría no ser necesaria si el único propósito es filtrar el DataFrame. Se puede filtrar directamente usando la ***serie booleana***, lo cual es más eficiente y claro.
#
# *   La comparación se hace con el string "**`Female`**", pero en el DataFrame original, los valores de '**`Sex`**' son "**`M`**" y "**`F`**". Esta inconsistencia hará que el código no funcione correctamente.

# %%
# Mejoras

# Crear serie booleana para filtrar por 'M'
new = df["Sex"] == "M"

# Mostrar filas donde 'Sex' es 'M'
print(df[new])
# Out:
#      Nume Sex Management         Echipa   New
# 0     Ion   M      False             Mk  True
# 1  Silviu   M       True        Finante  True
# 3  Vasile   M      False      Productie  True
# 4   Marin   M       True  Resurse Umane  True
# 5   Petru   M      False        Juridic  True

# %% [markdown]
# ---
# <a id="6"></a>
#
# ## **Filtrado de Datos con Condición Simple**
#
# ---

# %% [markdown]
# 👩‍💻 **La Autora Enache**

# %% [markdown]
# El tercer ejemplo de la autora, ilustra cómo ***filtrar*** un DataFrame en Pandas utilizando una ***única condición*** y el método **`query()`**.

# %% [markdown]
# El código realiza los siguientes pasos:
#
#
# 1.   Reemplaza los espacios en blanco en los nombres de las columnas con guiones bajos (`'_'`).
#
# 2.   Utiliza el método **`query()`** para filtrar las filas del DataFrame donde la columna '**`Management`**' es igual a **`True`**.
#
# 3. Muestra el DataFrame filtrado.

# %% [markdown]
# ```
# # Código Original de la Autora
#
# # importing pandas package
# import pandas as pd
#
# # making data frame from csv file
# data = pd.read_csv("angajat.csv")
#
# # replacing blank spaces with '_'
# data.columns =[column.replace(" ", "_") for column in data.columns]
#
# # filtering with query method
# data.query('Management == True', inplace = True)
#
# # display
# data
#
#
#
# ```

# %% [markdown]
# ⚠️ **Warning!**
#
# *  El dataset citado por la autora, **`angajat.csv`**, no está disponible. Por lo que, se asume que se utilizará el DataFrame (**`df`**) definido anteriormente.
#
# *  Adicionalmente, el código original de la autora está considerando "**`True`**" como booleano, pero debe ser string.

# %%
# Código Corregido

# Se está suponiendo que data = df

data = df

# replacing blank spaces with '_'
data.columns =[column.replace(" ", "_") for column in data.columns]

# filtering with query method
data.query('Management == "True"', inplace = True)

# display
data
# Out:
#      Nume Sex Management         Echipa   New
# 1  Silviu   M       True        Finante  True
# 4   Marin   M       True  Resurse Umane  True

# %% [markdown]
# **Comentarios Propios**
#
#
#
# *   En el DataFrame original **`df`**, los nombres de las columnas no contienen espacios, por lo que este paso es innecesario.
#
# *   En el DataFrame original, los valores de la columna '**`Management`**' son strings ('**`True`**' o '**`False`**'), no booleanos. Por lo tanto, la consulta debe ajustarse para coincidir con estos valores.

# %%
# Mejoras

df = original

# replacing blank spaces with '_'
df.columns =[column.replace(" ", "_") for column in df.columns]

# Ajustar la consulta para que coincida con los valores de tipo string
filtered_df = df.query('Management == "True"')

# Mostrar el DataFrame filtrado
print(filtered_df)
# Out:
#      Nume Sex Management         Echipa
# 1  Silviu   M       True        Finante
# 4   Marin   M       True  Resurse Umane

# %% [markdown]
# ---
# <a id="7"></a>
#
# ## **Filtrado de Datos con Condiciones Múltiples**
#
# ---

# %% [markdown]
# 👩‍💻 **La Autora Enache**

# %% [markdown]
# Este ejemplo muestra cómo aplicar un ***filtro basado en múltiples condiciones*** en un DataFrame usando el método **`query()`**.

# %% [markdown]
# El proceso es el siguiente:
#
#
#
# 1.   Se reemplazan los espacios en blanco en los nombres de las columnas por guiones bajos (`'_'`).
#
# 2.   Se filtra el DataFrame usando múltiples condiciones: '**`Management`**' igual a **`True`**, '**`Sex`**' igual a "**`M`**", '**`Echipa`**' igual a "**`Marketing`**", y '**`Nume`**' igual a "**`Ion`**".
#
# 3. Se muestra el DataFrame filtrado.

# %% [markdown]
# ```
# # Código Original de la Autora
#
# # importing pandas package
# import pandas as pd
#
# # making data frame from csv file
# data = pd.read_csv("angajat.csv")
#
# # replacing blank spaces with '_'
# data.columns =[column.replace(" ", "_") for column in data.columns]
#
# # filtering with query method
# data.query('Management == True
# and Sex =="M" and Echipa=="Marketing"
# and Nume =="Ion"', inplace = True)
#
# # display
# data
#
#
# ```

# %% [markdown]
# ⚠️ **Warning!**
#
# *  El dataset citado por la autora, **`angajat.csv`**, no está disponible. Por lo que, se asume que se utilizará el DataFrame (**`df`**) definido anteriormente.
#
# *  El código original de la autora está considerando "**`True`**" para "**`Management`**" como booleano, pero debe ser string.
#
# *  Adicionalmente, para poder encontrar coincidencias en la Query, es necesario modificar "**`Marketing`**" por "**`Mk`**" y consultar "**`Management`**" cuando sea "**`False`**".

# %%
# Código Corregido

# Se está suponiendo que dataset es el "original"

data2 = original

# replacing blank spaces with '_'
data2.columns =[column.replace(" ", "_") for column in data2.columns]

# filtering with query method
data2.query('Management == "False" and Sex =="M" and Echipa=="Mk" and Nume =="Ion"', inplace = True)

# display
data2
# Out:
#   Nume Sex Management Echipa
# 0  Ion   M      False     Mk

# %% [markdown]
# **Comentarios Propios**
#
# *   En el DataFrame **`df`**, los nombres de las columnas no contienen espacios, por lo que este paso es innecesario.
#
# *   En el DataFrame original, los valores de la columna '**`Management`**' son strings ('**`True`**' o '**`False`**'), no booleanos. Por lo tanto, la consulta debe ajustarse para coincidir con estos valores.
#
# *  Es recomendable evitar el uso de **`inplace=True`** para mantener el DataFrame original intacto y trabajar con una copia del DataFrame filtrado.

# %%
# Mejoras

df = original

# Ajustar la consulta con las condiciones correctas
filtered_df2 = df.query('Management == "False" and Sex == "M" and Echipa == "Mk" and Nume == "Ion"')

# Mostrar el DataFrame filtrado
print(filtered_df2)
# Out:
#   Nume Sex Management Echipa
# 0  Ion   M      False     Mk

# %% [markdown]
# ---
# <a id="8"></a>
#
# ## 📜 **Conclusiones**
#
# ---

# %% [markdown]
# Los ejemplos presentados en el paper "***Data Analysis with Pandas***" de Maria Cristina Enache ofrecen una visión valiosa sobre las capacidades fundamentales de **Pandas** en el análisis de datos.
#
# A través de estos ejemplos, se demuestra cómo realizar tareas esenciales como la selección y filtrado de datos en un DataFrame, tanto en condiciones simples como múltiples. Sin embargo, los ejemplos también revelaron ciertas ***áreas de mejora*** en términos de precisión, eficiencia y prácticas recomendadas en la manipulación de datos con Pandas.

# %% [markdown]
# Las correcciones y mejoras propuestas enfatizan la importancia de la consistencia de datos y la claridad en el código. Por ejemplo, ***ajustar las consultas*** para que coincidan con los tipos de datos reales en el DataFrame y evitar la creación innecesaria de columnas adicionales son prácticas que mejoran la eficiencia y la legibilidad del código.
#
# Además, se destacó la conveniencia de ***evitar modificar el DataFrame original***, una práctica recomendada en el análisis de datos para preservar la integridad de los datos originales. Estas mejoras no sólo reflejan un uso más eficiente de Pandas, sino que también facilitan la mantenibilidad y comprensión del código, aspectos cruciales en cualquier proyecto de análisis de datos.

# %% [markdown]
# ---
# <a id="9"></a>
#
# ## 📚 **Bibliografía**
#
# ---

# %% [markdown]
# * Chen, D. Y. (2022). **Pandas for Everyone: Python Data Analysis** (2nd ed.). Addison-Wesley Professional.
#
#
# *   Enache, Maria Cristina (2019). [Data Analysis with Pandas](https://web.archive.org/web/20191211022945id_/http://www.eia.feaa.ugal.ro/images/eia/2019_2/Enache1.pdf). *Journal of Data Analysis*.
#
#
# *  McKinney, W. (2017). **Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython** (2nd ed.). O'Reilly Media.
#
#
#
#
# *  Petrou, T. (2017). **Pandas Cookbook: Recipes for Scientific Computing, Time Series Analysis and Data Visualization using Python**. Packt Publishing
#
#
#
#
#
# *  VanderPlas, J. (2016). **Python Data Science Handbook: Essential Tools for Working with Data**. O'Reilly Media.
